# %%
library(ggplot2)
library(ggrepel)
library(EnhancedVolcano)

# %%
res=read.csv("/home/data1/Asthma/EnhancedVolcano/data.csv",sep = "\t")

# %%
res
# Out:
#     Assay         OlinkID  UniProt Panel        estimate     statistic
# 1   OSM           OID20574 P13725  Inflammation  1.2746262   4733.0
# 2   TNFAIP8       OID20433 O95379  Inflammation  1.7288061   4659.5
# 3   IL7           OID20535 P13232  Inflammation  0.9797515   4588.0
# 4   PSMG3         OID20549 Q9BT73  Inflammation  1.0929623   4563.0
# 5   VEGFA         OID20650 P15692  Inflammation  0.4287830   4538.0
# 6   STX8          OID20531 Q9UNK0  Inflammation  0.5673370   4465.0
# 7   LHPP          OID20749 Q9H008  Inflammation  0.8724069   4420.0
# 8   ANGPT1        OID20740 Q15389  Inflammation  1.1653669   4387.5
# 9   PKLR          OID20682 P30613  Inflammation  0.8239710   4380.0
# 10  PDGFB         OID20741 P01127  Inflammation  1.3684224   4379.0
# 11  DNPH1         OID20744 O43598  Inflammation  0.8540882   4349.0
# 12  IL10          OID20431 P22301  Inflammation  0.7741345   4329.0
# 13  EPHA1         OID20677 P21709  Inflammation  0.4225678   4305.5
# ...

# %%
res[res$p.value<=0.01,]$Assay
# Out:
# [1] "OSM"     "TNFAIP8" "IL7"     "PSMG3"   "VEGFA"   "STX8"    "LHPP"
# [8] "ANGPT1"

# %%
 p1<-EnhancedVolcano(res,
    lab = res$Assay,
    x = 'restimate',
    y = 'p.value',
    selectLab = res[res$p.value<=0.01,]$Assay,
    xlab="Effect size (CT vs CC)",
    title = '',
    subtitle = "",
    pCutoff = 0.05,
    FCcutoff = 0,
    pointSize =  -log(res$p.value)*0.8,
labCol = 'black',
    labFace = 'bold',
    colAlpha = 0.9,
    colGradient =  c('#FFBE7A',"#9ac9db"),
    caption = "",
    drawConnectors = TRUE,
    widthConnectors = 0.5,
    labSize = 4.0)

# %%
pdf("/home/data1/Asthma/EnhancedVolcano/EnhancedVolcano_plot.pdf", width = 6, height = 8)

p1+ggplot2::coord_cartesian(ylim=c(0, 3),xlim=c(-2, 2))+ 
    theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),legend.position="none",axis.text = element_text(size =1),axis.title = element_text(size =15))
dev.off()
# Out:
# Coordinate system already present. Adding new coordinate system, which will
# replace the existing one.
# png
#   2

# %%
-log(res$p.value)
# Out:
#   [1] 6.227266884 5.868567499 5.530033054 5.414077999 5.299371722 4.971554110
#   [7] 4.774748919 4.635106231 4.603177872 4.598928903 4.472384259 4.389006376
#  [13] 4.292044295 4.216474841 4.184004775 4.184004381 4.175906523 4.171860560
#  [19] 4.159733813 4.083342666 4.055377574 4.043421075 3.916985247 3.893500953
#  [25] 3.838977351 3.821533198 3.746396963 3.626584623 3.613391312 3.602101241
#  [31] 3.568335788 3.557116339 3.506841071 3.493864007 3.438517826 3.412838406
#  [37] 3.396380780 3.390902843 3.370855983 3.358129013 3.225032136 3.161234378
#  [43] 3.058017783 2.949641005 2.908851668 2.888560413 2.888560090 2.878440434
#  [49] 2.866654807 2.851536886 2.841479365 2.839805001 2.813076473 2.776522803
#  [55] 2.756681295 2.755030966 2.755030698 2.587572280 2.581170202 2.576372991
#  [61] 2.573177981 2.557228122 2.547681172 2.536564908 2.522305560 2.493900792
#  [67] 2.471913756 2.460954737 2.450018489 2.429769573 2.418898641 2.360286253
# ...
